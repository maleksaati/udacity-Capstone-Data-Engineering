# %%
import pandas as pd

# %%
fname = '../../data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat'
df = pd.read_sas(fname, 'sas7bdat', encoding="ISO-8859-1")
# Out:
# C:\Users\aalsa\AppData\Local\Temp\ipykernel_26796\4036090112.py:2: FutureWarning: In a future version of pandas all arguments of read_sas except for the argument 'filepath_or_buffer' will be keyword-only.
#   df = pd.read_sas(fname, 'sas7bdat', encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode i94addr  \
# 0    6.0  2016.0     4.0   692.0   692.0     XXX  20573.0      NaN     NaN
# 1    7.0  2016.0     4.0   254.0   276.0     ATL  20551.0      1.0      AL
# 2   15.0  2016.0     4.0   101.0   101.0     WAS  20545.0      1.0      MI
# 3   16.0  2016.0     4.0   101.0   101.0     NYC  20545.0      1.0      MA
# 4   17.0  2016.0     4.0   101.0   101.0     NYC  20545.0      1.0      MA
#
#    depdate  ...  entdepu  matflag  biryear   dtaddto gender insnum airline  \
# 0      NaN  ...        U      NaN   1979.0  10282016    NaN    NaN     NaN
# 1      NaN  ...        Y      NaN   1991.0       D/S      M    NaN     NaN
# 2  20691.0  ...      NaN        M   1961.0  09302016      M    NaN      OS
# 3  20567.0  ...      NaN        M   1988.0  09302016    NaN    NaN      AA
# 4  20567.0  ...      NaN        M   2012.0  09302016    NaN    NaN      AA
#
#          admnum  fltno visatype
# ...

# %%
fname = '../../data2/GlobalLandTemperaturesByCity.csv'
df = pd.read_csv(fname)

# %%
df
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
df =  pd.read_sas(filepath_or_buffer, format=None, index=None, encoding=None, chunksize=None, iterator=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df =  pd.read_sas(filepath_or_buffer, format=None, index=None, encoding=None, chunksize=None, iterator=False)
#
# NameError: name 'filepath_or_buffer' is not defined

# %%
immigration_data_fnames = ['../../data/18-83510-I94-Data-2016/*']

# %%
dfs = []
for fname in immigration_data_fnames:
    myiter = pd.read_sas(fname, 'sas7bdat', encoding='ISO-8859-1', chunksize=20)
    dfs.append(next(myiter))
    continue
# Out:
# C:\Users\aalsa\AppData\Local\Temp\ipykernel_26796\2794869857.py:3: FutureWarning: In a future version of pandas all arguments of read_sas except for the argument 'filepath_or_buffer' will be keyword-only.
#   myiter = pd.read_sas(fname, 'sas7bdat', encoding='ISO-8859-1', chunksize=20)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 3
#       1 dfs = []
#       2 for fname in immigration_data_fnames:
# ----> 3     myiter = pd.read_sas(fname, 'sas7bdat', encoding='ISO-8859-1', chunksize=20)
#       4     dfs.append(next(myiter))
#       5     continue
#
# File C:\Users\malek\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
